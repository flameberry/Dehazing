# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torchvision import transforms
from torch.utils.data import Dataset
from PIL import Image
import os

class HybridDehazeNet(nn.Module):
    def __init__(self):
        super(HybridDehazeNet, self).__init__()

        # Common layers
        self.relu = nn.ReLU(inplace=True)
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, padding=1)

        # LightDehaze_Net specific layers
        self.e_conv_layer1 = nn.Conv2d(3, 8, 1, 1, 0, bias=True)
        self.e_conv_layer2 = nn.Conv2d(8, 8, 3, 1, 1, bias=True)
        self.e_conv_layer3 = nn.Conv2d(8, 8, 5, 1, 2, bias=True)
        self.e_conv_layer4 = nn.Conv2d(16, 16, 7, 1, 3, bias=True)
        self.e_conv_layer5 = nn.Conv2d(16, 16, 3, 1, 1, bias=True)
        self.e_conv_layer6 = nn.Conv2d(16, 16, 3, 1, 1, bias=True)
        self.e_conv_layer7 = nn.Conv2d(32, 32, 3, 1, 1, bias=True)
        self.e_conv_layer8 = nn.Conv2d(56, 3, 3, 1, 1, bias=True)

        # Additional layers for the hybrid model
        self.deconv3 = nn.Conv2d(256, 128, kernel_size=3, padding=1)
        self.deconv2 = nn.Conv2d(128, 64, kernel_size=3, padding=1)
        self.deconv1 = nn.Conv2d(64, 3, kernel_size=3, padding=1)

    def forward(self, img):
        # Common feature extraction
        x1 = self.relu(self.conv1(img))
        x2 = self.relu(self.conv2(x1))
        x3 = self.relu(self.conv3(x2))

        # LightDehaze_Net specific feature extraction
        conv_layer1 = self.relu(self.e_conv_layer1(img))
        conv_layer2 = self.relu(self.e_conv_layer2(conv_layer1))
        conv_layer3 = self.relu(self.e_conv_layer3(conv_layer2))
        concat_layer1 = torch.cat((conv_layer1, conv_layer3), 1)
        conv_layer4 = self.relu(self.e_conv_layer4(concat_layer1))
        conv_layer5 = self.relu(self.e_conv_layer5(conv_layer4))
        conv_layer6 = self.relu(self.e_conv_layer6(conv_layer5))
        concat_layer2 = torch.cat((conv_layer4, conv_layer6), 1)
        conv_layer7 = self.relu(self.e_conv_layer7(concat_layer2))
        concat_layer3 = torch.cat((conv_layer2, conv_layer5, conv_layer7), 1)
        conv_layer8 = self.relu(self.e_conv_layer8(concat_layer3))

        # Hybrid model
        hybrid_layer1 = self.relu(self.deconv3(x3))
        hybrid_layer2 = self.relu(self.deconv2(hybrid_layer1))
        hybrid_layer3 = self.relu(self.deconv1(hybrid_layer2))

        dehaze_image = self.relu((conv_layer8 * hybrid_layer3) - conv_layer8 + 1)

        return dehaze_image

# Custom dataset class for input and target pairs
class CustomDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.hazy_folder = os.path.join(root_dir, 'hazy')
        self.clear_folder = os.path.join(root_dir, 'clear')
        self.hazy_images = os.listdir(self.hazy_folder)

    def __len__(self):
        return len(self.hazy_images)

    def __getitem__(self, idx):
        hazy_img_name = self.hazy_images[idx]
        hazy_path = os.path.join(self.hazy_folder, hazy_img_name)
        clear_path = os.path.join(self.clear_folder, hazy_img_name)  # Assuming filenames match

        hazy_image = Image.open(hazy_path).convert("RGB")
        clear_image = Image.open(clear_path).convert("RGB")

        if self.transform:
            hazy_image = self.transform(hazy_image)
            clear_image = self.transform(clear_image)

        return hazy_image, clear_image

# Set device (CPU/GPU)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define data transformations
transform = transforms.Compose([
    transforms.ToTensor(),
])

# Create custom dataset
train_dataset = CustomDataset('/content/drive/MyDrive/Data/Train', transform=transform)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=2)

# Initialize the model, loss function, and optimizer
model = HybridDehazeNet().to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 10

for epoch in range(num_epochs):
    for batch_idx, (hazy, clear) in enumerate(train_loader):
        hazy, clear = hazy.to(device), clear.to(device)

        # Forward pass
        output = model(hazy)

        # Compute the loss
        loss = criterion(output, clear)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Print training information
        if batch_idx % 100 == 0:
            print(f'Epoch [{epoch}/{num_epochs}], Batch [{batch_idx}/{len(train_loader)}], Loss: {loss.item():.4f}')

# Save the trained model
torch.save(model.state_dict(), 'hybrid_dehazenet_model.pth')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-5ed0e7ca6cd2> in <cell line: 58>()
#      56 # Load the trained model
#      57 model = DehazeNet().to(device)
# ---> 58 model.load_state_dict(torch.load('/content/drive/MyDrive/Data/dehazenet_model.pth'))
#      59 model.eval()
#      60
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#     984         pickle_load_args['encoding'] = 'utf-8'
#     985
# --> 986     with _open_file_like(f, 'rb') as opened_file:
#     987         if _is_zipfile(opened_file):
#     988             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     433 def _open_file_like(name_or_buffer, mode):
#     434     if _is_path(name_or_buffer):
# --> 435         return _open_file(name_or_buffer, mode)
#     436     else:
#     437         if 'w' in mode:
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     414 class _open_file(_opener):
#     415     def __init__(self, name, mode):
# --> 416         super().__init__(open(name, mode))
#     417
#     418     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Data/dehazenet_model.pth'

# %%
import torch
import torchvision.transforms as transforms
from PIL import Image
import os

# Load the trained model
model = LightweightDehazeNet()
model.load_state_dict(torch.load('lightweight_dehazenet_model.pth'))
model.eval()

# Set device (CPU/GPU)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# Define transformation for inference
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5, 0.5])
])

# Denormalization function to convert tensor back to image
def denormalize(tensor):
    tensor = tensor.cpu().numpy().transpose(1, 2, 0)
    tensor = (tensor + 1) / 2.0  # Denormalize to [0, 1] range
    tensor = (tensor * 255).astype('uint8')
    return Image.fromarray(tensor)

# Function to dehaze a single image
def dehaze_image(model, image_path, transform, device):
    hazy_image = Image.open(image_path).convert("RGBA")  # Assuming 4-channel images
    hazy_image = transform(hazy_image).unsqueeze(0).to(device)

    with torch.no_grad():
        model.eval()
        dehazed_image = model(hazy_image)

    dehazed_image = denormalize(dehazed_image.squeeze(0))

    return dehazed_image

# Directory containing hazy images for dehazing
hazy_images_dir = '/content/drive/MyDrive/Data/Train/hazy'

# Directory to save dehazed images
dehazed_images_dir = '/content/results4'

# Create the output directory if it doesn't exist
os.makedirs(dehazed_images_dir, exist_ok=True)

# Dehaze each image in the directory
for hazy_image_name in os.listdir(hazy_images_dir):
    hazy_image_path = os.path.join(hazy_images_dir, hazy_image_name)
    dehazed_image = dehaze_image(model, hazy_image_path, transform, device)

    # Save the dehazed image
    dehazed_image_name = f'dehazed_{hazy_image_name}'
    dehazed_image_path = os.path.join(dehazed_images_dir, dehazed_image_name)
    dehazed_image.save(dehazed_image_path)

    print(f'Dehazed image saved: {dehazed_image_path}')
# Out:
# Dehazed image saved: /content/results4/dehazed_18.png
# Dehazed image saved: /content/results4/dehazed_13.png
# Dehazed image saved: /content/results4/dehazed_12.png
# Dehazed image saved: /content/results4/dehazed_11.png
# Dehazed image saved: /content/results4/dehazed_17.png
# Dehazed image saved: /content/results4/dehazed_10.png
# Dehazed image saved: /content/results4/dehazed_1.png
# Dehazed image saved: /content/results4/dehazed_19.png
# Dehazed image saved: /content/results4/dehazed_16.png
# Dehazed image saved: /content/results4/dehazed_14.png
# Dehazed image saved: /content/results4/dehazed_15.png
# Dehazed image saved: /content/results4/dehazed_21.png
# Dehazed image saved: /content/results4/dehazed_20.png
# Dehazed image saved: /content/results4/dehazed_2.png
# Dehazed image saved: /content/results4/dehazed_24.png
# Dehazed image saved: /content/results4/dehazed_23.png
# Dehazed image saved: /content/results4/dehazed_22.png
# Dehazed image saved: /content/results4/dehazed_28.png
# Dehazed image saved: /content/results4/dehazed_3.png
# Dehazed image saved: /content/results4/dehazed_27.png
# Dehazed image saved: /content/results4/dehazed_29.png
# Dehazed image saved: /content/results4/dehazed_26.png
# Dehazed image saved: /content/results4/dehazed_25.png
# Dehazed image saved: /content/results4/dehazed_9.png
# Dehazed image saved: /content/results4/dehazed_8.png
# Dehazed image saved: /content/results4/dehazed_6.png
# Dehazed image saved: /content/results4/dehazed_5.png
# Dehazed image saved: /content/results4/dehazed_4.png
# Dehazed image saved: /content/results4/dehazed_30.png
# Dehazed image saved: /content/results4/dehazed_7.png
# Dehazed image saved: /content/results4/dehazed_85.png
# Dehazed image saved: /content/results4/dehazed_93.png
# Dehazed image saved: /content/results4/dehazed_89.png
# Dehazed image saved: /content/results4/dehazed_87.png
# Dehazed image saved: /content/results4/dehazed_91.png
# Dehazed image saved: /content/results4/dehazed_90.png
# Dehazed image saved: /content/results4/dehazed_88.png
# Dehazed image saved: /content/results4/dehazed_86.png
# Dehazed image saved: /content/results4/dehazed_59.png
# Dehazed image saved: /content/results4/dehazed_58.png
# Dehazed image saved: /content/results4/dehazed_57.png
# Dehazed image saved: /content/results4/dehazed_56.png
# Dehazed image saved: /content/results4/dehazed_55.png
# Dehazed image saved: /content/results4/dehazed_54.png
# Dehazed image saved: /content/results4/dehazed_53.png
# Dehazed image saved: /content/results4/dehazed_52.png
# Dehazed image saved: /content/results4/dehazed_51.png
# Dehazed image saved: /content/results4/dehazed_50.png
# Dehazed image saved: /content/results4/dehazed_49.png
# Dehazed image saved: /content/results4/dehazed_100.png
# Dehazed image saved: /content/results4/dehazed_99.png
# Dehazed image saved: /content/results4/dehazed_98.png
# Dehazed image saved: /content/results4/dehazed_96.png
# Dehazed image saved: /content/results4/dehazed_97.png
# Dehazed image saved: /content/results4/dehazed_95.png
# Dehazed image saved: /content/results4/dehazed_94.png
# Dehazed image saved: /content/results4/dehazed_92.png
# Dehazed image saved: /content/results4/dehazed_81.png
# Dehazed image saved: /content/results4/dehazed_80.png
# Dehazed image saved: /content/results4/dehazed_79.png
# Dehazed image saved: /content/results4/dehazed_78.png
# Dehazed image saved: /content/results4/dehazed_77.png
# Dehazed image saved: /content/results4/dehazed_76.png
# Dehazed image saved: /content/results4/dehazed_75.png
# Dehazed image saved: /content/results4/dehazed_74.png
# Dehazed image saved: /content/results4/dehazed_66.png
# Dehazed image saved: /content/results4/dehazed_60.png
# Dehazed image saved: /content/results4/dehazed_61.png
# Dehazed image saved: /content/results4/dehazed_71.png
# Dehazed image saved: /content/results4/dehazed_70.png
# Dehazed image saved: /content/results4/dehazed_65.png
# Dehazed image saved: /content/results4/dehazed_73.png
# Dehazed image saved: /content/results4/dehazed_62.png
# Dehazed image saved: /content/results4/dehazed_69.png
# Dehazed image saved: /content/results4/dehazed_72.png
# Dehazed image saved: /content/results4/dehazed_67.png
# Dehazed image saved: /content/results4/dehazed_68.png
# Dehazed image saved: /content/results4/dehazed_64.png
# Dehazed image saved: /content/results4/dehazed_63.png
# Dehazed image saved: /content/results4/dehazed_31.png
# Dehazed image saved: /content/results4/dehazed_33.png
# Dehazed image saved: /content/results4/dehazed_83.png
# Dehazed image saved: /content/results4/dehazed_35.png
# Dehazed image saved: /content/results4/dehazed_38.png
# Dehazed image saved: /content/results4/dehazed_37.png
# Dehazed image saved: /content/results4/dehazed_36.png
# Dehazed image saved: /content/results4/dehazed_34.png
# Dehazed image saved: /content/results4/dehazed_32.png
# Dehazed image saved: /content/results4/dehazed_84.png
# Dehazed image saved: /content/results4/dehazed_82.png
# Dehazed image saved: /content/results4/dehazed_48.png
# Dehazed image saved: /content/results4/dehazed_47.png
# Dehazed image saved: /content/results4/dehazed_46.png
# Dehazed image saved: /content/results4/dehazed_45.png
# Dehazed image saved: /content/results4/dehazed_44.png
# Dehazed image saved: /content/results4/dehazed_43.png
# Dehazed image saved: /content/results4/dehazed_42.png
# Dehazed image saved: /content/results4/dehazed_41.png
# Dehazed image saved: /content/results4/dehazed_40.png
# Dehazed image saved: /content/results4/dehazed_39.png
# Dehazed image saved: /content/results4/dehazed_174.png
# Dehazed image saved: /content/results4/dehazed_173.png
# Dehazed image saved: /content/results4/dehazed_172.png
# Dehazed image saved: /content/results4/dehazed_170.png
# Dehazed image saved: /content/results4/dehazed_171.png
# Dehazed image saved: /content/results4/dehazed_169.png
# Dehazed image saved: /content/results4/dehazed_165.png
# Dehazed image saved: /content/results4/dehazed_168.png
# Dehazed image saved: /content/results4/dehazed_167.png
# Dehazed image saved: /content/results4/dehazed_166.png
# Dehazed image saved: /content/results4/dehazed_131.png
# Dehazed image saved: /content/results4/dehazed_130.png
# Dehazed image saved: /content/results4/dehazed_200.png
# Dehazed image saved: /content/results4/dehazed_199.png
# Dehazed image saved: /content/results4/dehazed_198.png
# Dehazed image saved: /content/results4/dehazed_197.png
# Dehazed image saved: /content/results4/dehazed_194.png
# Dehazed image saved: /content/results4/dehazed_195.png
# Dehazed image saved: /content/results4/dehazed_180.png
# Dehazed image saved: /content/results4/dehazed_181.png
# Dehazed image saved: /content/results4/dehazed_191.png
# Dehazed image saved: /content/results4/dehazed_189.png
# Dehazed image saved: /content/results4/dehazed_184.png
# Dehazed image saved: /content/results4/dehazed_183.png
# Dehazed image saved: /content/results4/dehazed_192.png
# Dehazed image saved: /content/results4/dehazed_193.png
# Dehazed image saved: /content/results4/dehazed_188.png
# Dehazed image saved: /content/results4/dehazed_187.png
# Dehazed image saved: /content/results4/dehazed_177.png
# Dehazed image saved: /content/results4/dehazed_182.png
# Dehazed image saved: /content/results4/dehazed_190.png
# Dehazed image saved: /content/results4/dehazed_185.png
# Dehazed image saved: /content/results4/dehazed_178.png
# Dehazed image saved: /content/results4/dehazed_175.png
# Dehazed image saved: /content/results4/dehazed_176.png
# Dehazed image saved: /content/results4/dehazed_179.png
# Dehazed image saved: /content/results4/dehazed_196.png
# Dehazed image saved: /content/results4/dehazed_186.png
# Dehazed image saved: /content/results4/dehazed_147.png
# Dehazed image saved: /content/results4/dehazed_146.png
# Dehazed image saved: /content/results4/dehazed_145.png
# Dehazed image saved: /content/results4/dehazed_144.png
# Dehazed image saved: /content/results4/dehazed_143.png
# Dehazed image saved: /content/results4/dehazed_142.png
# Dehazed image saved: /content/results4/dehazed_141.png
# Dehazed image saved: /content/results4/dehazed_140.png
# Dehazed image saved: /content/results4/dehazed_139.png
# Dehazed image saved: /content/results4/dehazed_138.png
# Dehazed image saved: /content/results4/dehazed_137.png
# Dehazed image saved: /content/results4/dehazed_136.png
# Dehazed image saved: /content/results4/dehazed_135.png
# Dehazed image saved: /content/results4/dehazed_134.png
# Dehazed image saved: /content/results4/dehazed_133.png
# Dehazed image saved: /content/results4/dehazed_132.png
# Dehazed image saved: /content/results4/dehazed_159.png
# Dehazed image saved: /content/results4/dehazed_158.png
# Dehazed image saved: /content/results4/dehazed_157.png
# Dehazed image saved: /content/results4/dehazed_156.png
# Dehazed image saved: /content/results4/dehazed_155.png
# Dehazed image saved: /content/results4/dehazed_154.png
# Dehazed image saved: /content/results4/dehazed_153.png
# Dehazed image saved: /content/results4/dehazed_152.png
# Dehazed image saved: /content/results4/dehazed_151.png
# Dehazed image saved: /content/results4/dehazed_150.png
# Dehazed image saved: /content/results4/dehazed_149.png
# Dehazed image saved: /content/results4/dehazed_148.png
# Dehazed image saved: /content/results4/dehazed_108.png
# Dehazed image saved: /content/results4/dehazed_107.png
# Dehazed image saved: /content/results4/dehazed_106.png
# Dehazed image saved: /content/results4/dehazed_105.png
# Dehazed image saved: /content/results4/dehazed_104.png
# Dehazed image saved: /content/results4/dehazed_161.png
# Dehazed image saved: /content/results4/dehazed_163.png
# Dehazed image saved: /content/results4/dehazed_160.png
# Dehazed image saved: /content/results4/dehazed_162.png
# Dehazed image saved: /content/results4/dehazed_164.png
# Dehazed image saved: /content/results4/dehazed_112.png
# Dehazed image saved: /content/results4/dehazed_109.png
# Dehazed image saved: /content/results4/dehazed_110.png
# Dehazed image saved: /content/results4/dehazed_111.png
# Dehazed image saved: /content/results4/dehazed_116.png
# Dehazed image saved: /content/results4/dehazed_115.png
# Dehazed image saved: /content/results4/dehazed_114.png
# Dehazed image saved: /content/results4/dehazed_113.png
# Dehazed image saved: /content/results4/dehazed_121.png
# Dehazed image saved: /content/results4/dehazed_120.png
# Dehazed image saved: /content/results4/dehazed_119.png
# Dehazed image saved: /content/results4/dehazed_117.png
# Dehazed image saved: /content/results4/dehazed_118.png
# Dehazed image saved: /content/results4/dehazed_123.png
# Dehazed image saved: /content/results4/dehazed_124.png
# Dehazed image saved: /content/results4/dehazed_122.png
# Dehazed image saved: /content/results4/dehazed_101.png
# Dehazed image saved: /content/results4/dehazed_129.png
# Dehazed image saved: /content/results4/dehazed_128.png
# Dehazed image saved: /content/results4/dehazed_127.png
# Dehazed image saved: /content/results4/dehazed_126.png
# Dehazed image saved: /content/results4/dehazed_125.png
# Dehazed image saved: /content/results4/dehazed_103.png
# Dehazed image saved: /content/results4/dehazed_102.png

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
from PIL import Image
import os

# Define the dehazing model architecture
class DehazeNet(nn.Module):
    def __init__(self):
        super(DehazeNet, self).__init__()

        # Encoder layers
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(64, 128, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(128, 256, kernel_size=3, stride=1, padding=1)

        # Decoder layers
        self.deconv3 = nn.ConvTranspose2d(256, 128, kernel_size=3, stride=1, padding=1)
        self.deconv2 = nn.ConvTranspose2d(128, 64, kernel_size=3, stride=1, padding=1)
        self.deconv1 = nn.ConvTranspose2d(64, 3, kernel_size=3, stride=1, padding=1)

    def forward(self, x):
        # Encoder
        x1 = F.relu(self.conv1(x))
        x2 = F.relu(self.conv2(x1))
        x3 = F.relu(self.conv3(x2))

        # Decoder
        x_deconv3 = F.relu(self.deconv3(x3))
        x_deconv2 = F.relu(self.deconv2(x_deconv3 + x2))
        x_deconv1 = F.sigmoid(self.deconv1(x_deconv2 + x1))

        return x_deconv1

# Load the trained model
model = DehazeNet()
model.load_state_dict(torch.load('dehazenet_model.pth'))
model.eval()

# Set device (CPU/GPU)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# Define transformation for inference
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# Denormalization function to convert tensor back to image
def denormalize(tensor):
    tensor = tensor.cpu().numpy().transpose(1, 2, 0)
    tensor = (tensor + 1) / 2.0  # Denormalize to [0, 1] range
    tensor = (tensor * 255).astype('uint8')
    return Image.fromarray(tensor)

# Function to dehaze a single image
def dehaze_image(model, image_path, transform, device):
    hazy_image = Image.open(image_path).convert("RGB")  # Assuming 3-channel images
    hazy_image = transform(hazy_image).unsqueeze(0).to(device)

    with torch.no_grad():
        model.eval()
        dehazed_image = model(hazy_image)

    dehazed_image = denormalize(dehazed_image.squeeze(0))

    return dehazed_image

# Directory containing hazy images for dehazing
hazy_images_dir = '/content/drive/MyDrive/Data/Test/hazy'

# Directory to save dehazed images
dehazed_images_dir = '/content/results4'

# Create the output directory if it doesn't exist
os.makedirs(dehazed_images_dir, exist_ok=True)

# Dehaze each image in the directory
for hazy_image_name in os.listdir(hazy_images_dir):
    hazy_image_path = os.path.join(hazy_images_dir, hazy_image_name)
    dehazed_image = dehaze_image(model, hazy_image_path, transform, device)

    # Save the dehazed image
    dehazed_image_name = f'dehazed_{hazy_image_name}'
    dehazed_image_path = os.path.join(dehazed_images_dir, dehazed_image_name)
    dehazed_image.save(dehazed_image_path)

    print(f'Dehazed image saved: {dehazed_image_path}')
